# %% [markdown]
# # Web Scrapping Demo
#
# The following demo only shows two pages of Taco Bell's online menu being web scrapped and cleaned into a dataset that can be used for an optimization model.
#
# **Note:** This demo provides an example of my web scrapping service. The same methodology can be applied to ANY website for ANY use case to support your business needs.

# %%
# Developled on Python version 3.11.4

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from datetime import date

from time import sleep
from bs4 import BeautifulSoup
import pandas as pd

from webscrapping_functions import *

today=date.today()
print(today)
# Out:
# 2024-08-27

# %%
driver = webdriver.Chrome()
menu_data = pulling_data(driver)
# Out:
# All of the Double Stacked Taco data added to the master dataset
# All of the Soft Taco data added to the master dataset
# All of the Soft Taco Supreme® data added to the master dataset
# All of the Spicy Potato Soft Taco data added to the master dataset
# All of the Crunchy Taco data added to the master dataset
# All of the Crunchy Taco Supreme® data added to the master dataset
# All of the Nacho Cheese Doritos® Locos Tacos data added to the master dataset
# All of the Nacho Cheese Doritos® Locos Tacos Supreme® data added to the master dataset
# All of the Chalupa Supreme® data added to the master dataset
# All of the Black Bean Chalupa Supreme® data added to the master dataset
# All of the Cheesy Gordita Crunch data added to the master dataset
# All of the Doritos® Cheesy Gordita Crunch - Nacho Cheese data added to the master dataset
#
# The Tacos section has been sucessfully pulled
#
# All individual items from Taco Bell's menu have been acquired

# %%
driver.quit()

# %%
menu_data_df = pd.DataFrame(menu_data)
menu_data_df.info
print(menu_data_df.shape)
# Out:
# (12, 18)

# %%
menu_data_df.head()
# Out:
#                 item_name  price menu_section  Calories  Total Fat (g)  \
# 0     Double Stacked Taco   1.99        Tacos     320.0           16.0
# 1               Soft Taco   1.89        Tacos     180.0            8.0
# 2      Soft Taco Supreme®   2.99        Tacos     210.0           10.0
# 3  Spicy Potato Soft Taco   1.29        Tacos     240.0           12.0
# 4            Crunchy Taco   1.89        Tacos     170.0           10.0
#
#    Saturated Fat (g)  Trans Fat (g)  Cholesterol (mg)  Sodium (mg)  \
# 0                5.0            0.0              25.0        600.0
# 1                4.0            0.0              25.0        490.0
# 2                5.0            0.0              30.0        510.0
# 3                3.0            0.0              10.0        470.0
# 4                4.0            0.0              25.0        300.0
#
#    Total Carbohydrates (g)  Dietary Fiber (g)  Sugars (g)  Includes (g)  \
# ...

# %%
menu_data_df.to_csv(f"../data/uncleaned_taco_bell_menu_items_{today}.csv")

# %% [markdown]
# ### Data Cleaning

# %%
# Example usage:
clean_taco_bell_menu("../data/uncleaned_taco_bell_menu_items_2024-08-27.csv")
# Out:
#                                         item_name  price menu_section  \
# 0                             Double Stacked Taco   1.99        Tacos
# 1                                       Soft Taco   1.89        Tacos
# 2                              Soft Taco Supreme®   2.99        Tacos
# 3                          Spicy Potato Soft Taco   1.29        Tacos
# 4                                    Crunchy Taco   1.89        Tacos
# 5                           Crunchy Taco Supreme®   2.99        Tacos
# 6               Nacho Cheese Doritos® Locos Tacos   2.99        Tacos
# 7      Nacho Cheese Doritos® Locos Tacos Supreme®   3.89        Tacos
# 8                                Chalupa Supreme®   6.09        Tacos
# 9                     Black Bean Chalupa Supreme®   5.19        Tacos
# 10                          Cheesy Gordita Crunch   5.99        Tacos
# 11  Doritos® Cheesy Gordita Crunch - Nacho Cheese   6.19        Tacos
#
# ...
