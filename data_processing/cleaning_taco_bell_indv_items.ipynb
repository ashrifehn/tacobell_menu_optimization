# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Reading in the data
menu_data_df = pd.read_csv("../data/uncleaned_indv_items.csv", index_col=0)
print(menu_data_df.shape)

menu_data_df.info()
# Out:
# (106, 18)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 106 entries, 0 to 105
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   item_name                106 non-null    object
#  1   price                    106 non-null    float64
#  2   menu_section             106 non-null    object
#  3   Calories                 106 non-null    float64
#  4   Total Fat (g)            106 non-null    float64
#  5   Saturated Fat (g)        106 non-null    float64
#  6   Trans Fat (g)            106 non-null    float64
#  7   Cholesterol (mg)         106 non-null    float64
#  8   Sodium (mg)              106 non-null    float64
#  9   Total Carbohydrates (g)  106 non-null    float64
#  10  Dietary Fiber (g)        106 non-null    float64
#  11  Sugars (g)               106 non-null    float64
#  12  Includes (g)             106 non-null    float64
#  13  Protein (g)              106 non-null    float64
#  14  Vitamin D (mcg)          106 non-null    float64
#  15  Calcium (mg)             106 non-null    float64
#  16  Iron (mg)                106 non-null    float64
#  17  Potassium (mg)           106 non-null    float64
# dtypes: float64(16), object(2)
# memory usage: 15.7+ KB

# %% [markdown]
# - As we can see all the NaN values are only for alleregen info, so i will be replacing all NaN with zero
# - Next, we will combine the `Sugars (g)` and `Includes (g)` into one column named `Total Sugars (g)`

# %%
menu_data_df.fillna(0, inplace=True)

menu_data_df['Total Sugars (g)'] = menu_data_df['Sugars (g)'] + menu_data_df['Includes (g)']

del menu_data_df['Sugars (g)']
del menu_data_df['Includes (g)']

menu_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 106 entries, 0 to 105
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   item_name                106 non-null    object
#  1   price                    106 non-null    float64
#  2   menu_section             106 non-null    object
#  3   Calories                 106 non-null    float64
#  4   Total Fat (g)            106 non-null    float64
#  5   Saturated Fat (g)        106 non-null    float64
#  6   Trans Fat (g)            106 non-null    float64
#  7   Cholesterol (mg)         106 non-null    float64
#  8   Sodium (mg)              106 non-null    float64
#  9   Total Carbohydrates (g)  106 non-null    float64
#  10  Dietary Fiber (g)        106 non-null    float64
#  11  Protein (g)              106 non-null    float64
#  12  Vitamin D (mcg)          106 non-null    float64
#  13  Calcium (mg)             106 non-null    float64
#  14  Iron (mg)                106 non-null    float64
#  15  Potassium (mg)           106 non-null    float64
#  16  Total Sugars (g)         106 non-null    float64
# dtypes: float64(15), object(2)
# memory usage: 14.9+ KB

# %% [markdown]
# - If price is less than $1.00 that means it is a sauce packet and will get dropped from the data frame

# %%
menu_data_df = menu_data_df[menu_data_df['price'] >= 1.00]
menu_data_df.shape
# Out:
# (93, 17)

# %%
menu_data_df.head()
# Out:
#                 item_name  price menu_section  Calories  Total Fat (g)  \
# 0               Soft Taco   1.89        Tacos     180.0            8.0
# 1      Soft Taco Supreme®   2.89        Tacos     210.0           10.0
# 2  Spicy Potato Soft Taco   1.10        Tacos     240.0           12.0
# 3            Crunchy Taco   1.89        Tacos     170.0           10.0
# 4   Crunchy Taco Supreme®   2.89        Tacos     190.0           11.0
#
#    Saturated Fat (g)  Trans Fat (g)  Cholesterol (mg)  Sodium (mg)  \
# 0                4.0            0.0              25.0        500.0
# 1                5.0            0.0              25.0        510.0
# 2                3.0            0.0              10.0        480.0
# 3                3.5            0.0              25.0        300.0
# 4                4.5            0.0              25.0        320.0
#
#    Total Carbohydrates (g)  Dietary Fiber (g)  Protein (g)  Vitamin D (mcg)  \
# 0                     18.0                3.0          9.0              0.0
# 1                     20.0                3.0         10.0              0.0
# 2                     28.0                2.0          5.0              0.0
# 3                     13.0                3.0          8.0              0.0
# 4                     15.0                3.0          8.0              0.0
#
#    Calcium (mg)  Iron (mg)  Potassium (mg)  Total Sugars (g)
# 0         110.0        1.7           130.0               2.0
# 1         130.0        1.7           200.0               3.0
# 2         110.0        1.3           270.0               2.0
# 3          70.0        0.9           140.0               1.0
# 4          80.0        0.9           200.0               2.0

# %% [markdown]
# # Removing duplicates and limited time items

# %% [markdown]
# ## Checking and removing duplicates

# %%
# generate count statistics of duplicate entries
if len(menu_data_df[menu_data_df.item_name.duplicated()]) > 0:
    print("No. of duplicated entries: ", len(menu_data_df[menu_data_df.item_name.duplicated()]))
else:
    print("No duplicated entries found")
# Out:
# No. of duplicated entries:  20

# %%
# Viewing the duplated rows
duplated_rows = menu_data_df.loc[menu_data_df.item_name.duplicated(), :]
duplated_rows
# Out:
#                           item_name  price     menu_section  Calories  \
# 67     Chips and Nacho Cheese Sauce   2.59           Nachos     220.0
# 68                     Bean Burrito   1.99  Veggie Cravings     350.0
# 69     Cheesy Bean and Rice Burrito   1.00  Veggie Cravings     420.0
# 70            Fiesta Veggie Burrito   2.00  Veggie Cravings     570.0
# 71           Spicy Potato Soft Taco   1.10  Veggie Cravings     240.0
# 72      Black Bean Chalupa Supreme®   4.19  Veggie Cravings     340.0
# 73   Black Bean Crunchwrap Supreme®   5.39  Veggie Cravings     520.0
# 74             Veggie Mexican Pizza   5.19  Veggie Cravings     470.0
# 76                   Cheesy Roll Up   1.00  Veggie Cravings     180.0
# 77           Cheesy Fiesta Potatoes   2.59  Veggie Cravings     240.0
# 78     Chips and Nacho Cheese Sauce   2.59  Veggie Cravings     220.0
# 79                      Black Beans   1.49  Veggie Cravings      50.0
# 80             Black Beans and Rice   1.49  Veggie Cravings     160.0
# 81                  Pintos N Cheese   2.39  Veggie Cravings     170.0
# 82                  Cinnamon Twists   1.00  Veggie Cravings     170.0
# 83        Cinnabon Delights® 2 Pack   2.19  Veggie Cravings     170.0
# 84       Cinnabon Delights® 12 Pack   6.89  Veggie Cravings    1010.0
# 86         Power Menu Bowl - Veggie   6.79            Bowls     420.0
# 103       Cinnabon Delights® 2 Pack   2.19        Breakfast     170.0
# 104      Cinnabon Delights® 12 Pack   6.89        Breakfast    1010.0
#
#      Total Fat (g)  Saturated Fat (g)  Trans Fat (g)  Cholesterol (mg)
# 67                1.0
# 68                5.0
# 69                5.0
# 70                6.0
# 71                2.0
# 72                5.0
# 73                8.0
# 74                4.0
# 76                2.0
# 77                1.0
# 78                1.0
# 79                0.0
# 80                1.0
# 81                2.0
# 82               20.0
# 83               18.0
# 84              104.0
# 86                3.0
# 103              18.0
# 104             104.0

# %%
# Removing duplates from item_name column
menu_data_df = menu_data_df.drop_duplicates(subset=['item_name'])
menu_data_df.shape
# Out:
# (73, 17)

# %%
# generate count statistics of duplicate entries
if len(menu_data_df[menu_data_df.item_name.duplicated()]) > 0:
    print("No. of duplicated entries: ", len(menu_data_df[menu_data_df.item_name.duplicated()]))
else:
    print("No duplicated entries found")
# Out:
# No duplicated entries found

# %% [markdown]
# ## Dropping limited time items

# %%
# Dropping limited time items 
menu_data_df = menu_data_df.drop(menu_data_df[menu_data_df['item_name']=='Steak and Bacon Grilled Cheese Burrito'].index)
menu_data_df = menu_data_df.drop(menu_data_df[menu_data_df['item_name']=='Strawberry Twists'].index)
menu_data_df = menu_data_df.drop(menu_data_df[menu_data_df['item_name']=='Wild Strawberry Creme Delight Freeze'].index)
menu_data_df = menu_data_df.drop(menu_data_df[menu_data_df['item_name']=='Blue Raspberry Freeze'].index)
menu_data_df = menu_data_df.drop(menu_data_df[menu_data_df['item_name']=='Breakfast Taco Sausage'].index)
menu_data_df = menu_data_df.drop(menu_data_df[menu_data_df['item_name']=='Breakfast Taco Bacon'].index)
menu_data_df = menu_data_df.drop(menu_data_df[menu_data_df['item_name']=='Breakfast Taco Potato'].index)

# Steak and Bacon Grilled Cheese Burrito
# Strawberry Twists
# Wild Strawberry Creme Delight Freeze
# Blue Raspberry Freeze
# Breakfast Taco Sausage
# Breakfast Taco Bacon
# Breakfast Taco Potato

# %%
print(menu_data_df.shape)
menu_data_df.head()
# Out:
# (67, 17)
#                 item_name  price menu_section  Calories  Total Fat (g)  \
# 0               Soft Taco   1.89        Tacos     180.0            8.0
# 1      Soft Taco Supreme®   2.89        Tacos     210.0           10.0
# 2  Spicy Potato Soft Taco   1.10        Tacos     240.0           12.0
# 3            Crunchy Taco   1.89        Tacos     170.0           10.0
# 4   Crunchy Taco Supreme®   2.89        Tacos     190.0           11.0
#
#    Saturated Fat (g)  Trans Fat (g)  Cholesterol (mg)  Sodium (mg)  \
# 0                4.0            0.0              25.0        500.0
# 1                5.0            0.0              25.0        510.0
# 2                3.0            0.0              10.0        480.0
# 3                3.5            0.0              25.0        300.0
# 4                4.5            0.0              25.0        320.0
#
#    Total Carbohydrates (g)  Dietary Fiber (g)  Protein (g)  Vitamin D (mcg)  \
# 0                     18.0                3.0          9.0              0.0
# 1                     20.0                3.0         10.0              0.0
# 2                     28.0                2.0          5.0              0.0
# 3                     13.0                3.0          8.0              0.0
# 4                     15.0                3.0          8.0              0.0
#
#    Calcium (mg)  Iron (mg)  Potassium (mg)  Total Sugars (g)
# 0         110.0        1.7           130.0               2.0
# 1         130.0        1.7           200.0               3.0
# 2         110.0        1.3           270.0               2.0
# 3          70.0        0.9           140.0               1.0
# 4          80.0        0.9           200.0               2.0

# %%
# Ready to use dataset
menu_data_df.to_csv("../data/cleaned_indv_items.csv.csv")
